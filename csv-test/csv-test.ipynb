# %%
# -------- Autogenerated code --------n# modifications to this cell will be overwrittennn# Import CSV data into a pandas data frame: n# see also: http://pandas.pydata.org/nimport pandasnmore-data = Nonenwith open(more-data.csv, r) as fp:n    more-data = pandas.read_csv(csv_input, error_bad_lines=False)n

# %%
# -------- Autogenerated code --------n# modifications to this cell will be overwrittennn# Import CSV data into a pandas data frame: n# see also: http://pandas.pydata.org/nimport pandasnexample-data = Nonenwith open(example-data.csv, r) as fp:n    example-data = pandas.read_csv(csv_input, error_bad_lines=False)n

# %%
import pandas
import os
# Adam's test change. again

# %%
# This cell defines our inputs
csv_input = open('wonambi-input/example-data.csv', 'r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-8b59791c4fdc> in <module>()
#       1 # This cell defines our inputs
# ----> 2 csv_input = open('wonambi-input/example-data.csv', 'r')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'wonambi-input/example-data.csv'

# %%
# Read and convert
df = pandas.read_csv(csv_input, error_bad_lines=False)
df = df.convert_objects(convert_numeric=True)

#Write output
if not os.path.exists('wonambi-output'):
    os.makedirs('wonambi-output')
csv_output = open('wonambi-output/output-data.csv', 'w')
df.to_csv(csv_output)
csv_output.close()
