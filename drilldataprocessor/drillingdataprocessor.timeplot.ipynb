# %%
# %pylab inline
import pandas
import numpy
import scipy.stats as stats
import matplotlib.pyplot as plt
import sys
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
inputFolder = "./input_files/" # make sure this folder exists
outputFolder = "./output_files/"  # make sure this folder exists
dataFile = "MSDP01_FMS.csv"
data = pandas.read_csv(dataFile, parse_dates = {'Timestamp': ['Time']})
print(numpy.asarray(data.keys()))
# Out:
# ['Timestamp' 'Depth_m' 'pH' 'Temperature' 'ORP_corrected' 'Conductivity_uS'
#  'Cond_ppt' 'Cond_recalc' 'Cl_ppm' 'Cl_mV' 'Ca_ppm' 'Ca_recalc'
#  'Ca_rounded' 'Ca_mV' 'K_ppm' 'K_mV' 'NH4_ppm' 'NH4_rounded' 'NH4_mV'
#  'F_ppm' 'F_rounded' 'F_mV' 'NO3_ppm' 'NO3_mV' 'NO3_recal' 'S_mV' 'Br_ppm'
#  'Br_mV' 'Unnamed: 28' 'Cond/Cl' 'Br/Cl' 'Br/Cond' 'NH4/K' 'NH4/S2-'
#  'Br/Cond.1' 'Br/S' 'Unnamed: 36' 'Cl_slope' 'Br_slope' 'Ca_slope'
#  'K_slope' 'NH4_slope' 'F_slope' 'NO3_slope' 'S_slope' 'Temp_slope'
#  'Eh_slope' 'pH_slope' 'Cond_slope' 'Unnamed: 49' 'Cumulative slope'
#  'Cl_CS' 'Br_CS' 'Ca_CS' 'K_CS' 'NH4_CS' 'F_CS' 'NO3_CS' 'S_CS' 'Temp_CS'
#  'Eh_CS' 'pH_CS' 'Cond_CS']

# %%
data.head()
# Out:
#             Timestamp  Depth_m    pH  Temperature  ORP_corrected  \
# 0 2015-06-08 09:18:00   117.50  8.08         18.1            2.3
# 1 2015-06-08 09:19:00   117.55  8.08         18.0            4.3
# 2 2015-06-08 09:19:00   117.60  8.09         18.0            5.6
# 3 2015-06-08 09:20:00   117.64  8.13         18.3            2.3
# 4 2015-06-08 09:20:00   117.69  8.17         18.6            1.4
#
#    Conductivity_uS  Cond_ppt  Cond_recalc   Cl_ppm  Cl_mV   ...     Ca_CS  \
# 0              NaN       NaN          NaN  2728.08   96.6   ...       NaN
# 1              NaN       NaN          NaN  2644.30   97.3   ...       1.3
# 2              NaN       NaN          NaN  2748.17   96.5   ...      -1.3
# 3              NaN       NaN          NaN  2927.74   95.1   ...       0.8
# 4              NaN       NaN          NaN  3119.05   93.7   ...       1.8
#
#    K_CS  NH4_CS  F_CS  NO3_CS  S_CS  Temp_CS  Eh_CS  pH_CS  Cond_CS
# ...

# %%
plot_cols = [i for i in data.keys() if i != 'Timestamp']

# %%
for i in plot_cols:
    plt.plot(data[i], data['Depth_m'], 'o');
    plt.gca().invert_yaxis()
    plt.suptitle (i)
    plt.show()
# Out:
# C:\Users\rei198\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:227: RuntimeWarning: All-NaN axis encountered
#   warnings.warn("All-NaN axis encountered", RuntimeWarning)

# %%
ORP_corr = data['ORP']+200
plt.plot(ORP_corr, data['Timestamp']);
plt.gca().invert_yaxis()

# %%
plt.plot(data['K_mV'],data['NH4_mV'], 'o')

# %%
NH4_corr = data['NH4_mV']/data['K_mV']-average(data['NH4_mV']/data['K_mV'])
plt.plot(NH4_corr, data['Depth_m'])
plt.gca().invert_yaxis()

# %%
plt.plot(data['Br_mV'],data['Cl_mV'], 'o')
